# %%
# %matplotlib inline
import numpy as np
from VATFunctions import VideoAlignment
vat = VideoAlignment("demo.mp4")
vat.DisplayFrame(10)
registration_points = np.array([
    [550, 450],
    [1500, 400],
    [1500, 690],
    [550, 750]
])
vat.TransformVideo(registration_points)
# Out:
# Done
